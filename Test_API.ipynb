# %%
import requests

data = {
    'race':'Caucasian',
    'gender':'Female',
    'age':'[50-60)',
    'admission_type_id':1,
    'discharge_disposition_id':1,
    'admission_source_id':7,
    'time_in_hospital':3,
    'num_lab_procedures':59,
    'num_procedures':0,
    'num_medications':18,
    'number_outpatient':0,
    'number_emergency':0,
    'number_inpatient':0,
    'diag_1':'276',
    'diag_2':'250.01',
    'diag_3':'255',
    'number_diagnoses':9,
    'number_of_diabetes_medications':1,
    'prior_readmissions':0,

}

r = requests.post('http://127.0.0.1:8000/predict', json=data)

# %%
import json

json.loads(r.text)['prediction']
# Out:
# 1.0

# %%
r.text
# Out:
# '{"prediction":1.0,"predicted_probability":0.594642426925061}'
